# %%
import pandas as pd

# %%
a = pd.read_excel('빅콘/dam_data.xlsx', encoding = 'utf-8')

# %%
a
# Out:
#       홍수사상번호       연    월     일    시간         유입량 데이터집단 1 Unnamed: 7  \
# 0        NaN     NaN  NaN   NaN   NaN         NaN  유역평균강수    강우(A지역)
# 1        1.0  2006.0  7.0  10.0   8.0  189.100000     6.4          7
# 2        1.0  2006.0  7.0  10.0   9.0  216.951962     6.3          7
# 3        1.0  2006.0  7.0  10.0  10.0  251.424419     6.4          7
# 4        1.0  2006.0  7.0  10.0  11.0  302.812199     7.3          7
# ...      ...     ...  ...   ...   ...         ...     ...        ...
# 3047    26.0  2018.0  7.0   7.0  17.0         NaN  2.3689          1
# 3048    26.0  2018.0  7.0   7.0  18.0         NaN  2.3689          1
# 3049    26.0  2018.0  7.0   7.0  19.0         NaN  2.3689          1
# 3050    26.0  2018.0  7.0   7.0  20.0         NaN  2.3689          1
# 3051    26.0  2018.0  7.0   7.0  21.0         NaN  2.3689          1
#
#      Unnamed: 8 Unnamed: 9  ... Unnamed: 38 Unnamed: 39 Unnamed: 40 데이터 집단 6  \
# ...

# %%
a = pd.read_excel('빅콘/dam_data.xlsx', encoding = 'utf-8', header = 1)

# %%
a.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', '유역평균강수', '강우(A지역)', '강우(B지역)', '강우(C지역)', '강우(D지역)',
#        '수위(E지역)', '수위(D지역)', '유역평균강수.1', '강우(A지역).1', '강우(B지역).1', '강우(C지역).1',
#        '강우(D지역).1', '수위(E지역).1', '수위(D지역).1', '유역평균강수.2', '강우(A지역).2',
#        '강우(B지역).2', '강우(C지역).2', '강우(D지역).2', '수위(E지역).2', '수위(D지역).2',
#        '유역평균강수.3', '강우(A지역).3', '강우(B지역).3', '강우(C지역).3', '강우(D지역).3',
#        '수위(E지역).3', '수위(D지역).3', '유역평균강수.4', '강우(A지역).4', '강우(B지역).4',
#        '강우(C지역).4', '강우(D지역).4', '수위(E지역).4', '수위(D지역).4', '유역평균강수.5',
#        '강우(A지역).5', '강우(B지역).5', '강우(C지역).5', '강우(D지역).5', '수위(E지역).5',
#        '수위(D지역).5'],
#       dtype='object')

# %%
a.rename(columns = {'Unnamed: 0':'홍수사상번호', 'Unnamed: 1':'연','Unnamed: 2':'월','Unnamed: 3':'일',
                   'Unnamed: 4':'시간','Unnamed: 5':'유입량'}, inplace = True)

# %%
a
# Out:
#       홍수사상번호     연  월   일  시간         유입량  유역평균강수  강우(A지역)  강우(B지역)  강우(C지역)  \
# 0          1  2006  7  10   8  189.100000  6.4000        7        7        7
# 1          1  2006  7  10   9  216.951962  6.3000        7        8        7
# 2          1  2006  7  10  10  251.424419  6.4000        7        9        7
# 3          1  2006  7  10  11  302.812199  7.3000        7       10        7
# 4          1  2006  7  10  12  384.783406  8.2000        7       12        8
# ...      ...   ... ..  ..  ..         ...     ...      ...      ...      ...
# 3046      26  2018  7   7  17         NaN  2.3689        1        0        0
# 3047      26  2018  7   7  18         NaN  2.3689        1        0        0
# 3048      26  2018  7   7  19         NaN  2.3689        1        0        0
# 3049      26  2018  7   7  20         NaN  2.3689        1        0        0
# 3050      26  2018  7   7  21         NaN  2.3689        1        0        0
#
# ...

# %%
b = a.loc[:,'유입량']

# %%
# a.drop('유입량', axis = 1, inplace = True)

# %%
b = pd.DataFrame(b)

# %%
b
# Out:
#              유입량
# 0     189.100000
# 1     216.951962
# 2     251.424419
# 3     302.812199
# 4     384.783406
# ...          ...
# 3046         NaN
# 3047         NaN
# 3048         NaN
# 3049         NaN
# 3050         NaN
#
# [3051 rows x 1 columns]

# %%
a.drop(a[a['홍수사상번호']==26].index, inplace = True)

# %%
a
# Out:
#       홍수사상번호     연  월   일  시간         유입량   유역평균강수  강우(A지역)  강우(B지역)  강우(C지역)  \
# 0          1  2006  7  10   8  189.100000   6.4000        7        7        7
# 1          1  2006  7  10   9  216.951962   6.3000        7        8        7
# 2          1  2006  7  10  10  251.424419   6.4000        7        9        7
# 3          1  2006  7  10  11  302.812199   7.3000        7       10        7
# 4          1  2006  7  10  12  384.783406   8.2000        7       12        8
# ...      ...   ... ..  ..  ..         ...      ...      ...      ...      ...
# 2886      25  2017  7  18  18  513.368437  22.7836        6        0        1
# 2887      25  2017  7  18  19  502.846843   8.2586        2        0        1
# 2888      25  2017  7  18  20  491.954805   4.1089        1        0        1
# 2889      25  2017  7  18  21  481.103083   3.3854        1        0        1
# 2890      25  2017  7  18  22  470.458109   3.2841        1        0        1
#
# ...

# %%
b.dropna(inplace = True)

# %%
a.drop('홍수사상번호', axis  =1, inplace = True)

# %%
a.isna().sum()
# Out:
# 연            0
# 월            0
# 일            0
# 시간           0
# 유입량          0
# 유역평균강수       0
# 강우(A지역)      0
# 강우(B지역)      0
# 강우(C지역)      0
# 강우(D지역)      0
# 수위(E지역)      0
# 수위(D지역)      0
# 유역평균강수.1     0
# 강우(A지역).1    0
# 강우(B지역).1    0
# 강우(C지역).1    0
# 강우(D지역).1    0
# 수위(E지역).1    0
# 수위(D지역).1    0
# 유역평균강수.2     0
# 강우(A지역).2    0
# 강우(B지역).2    0
# 강우(C지역).2    0
# 강우(D지역).2    0
# 수위(E지역).2    0
# 수위(D지역).2    0
# 유역평균강수.3     0
# 강우(A지역).3    0
# 강우(B지역).3    0
# 강우(C지역).3    0
# 강우(D지역).3    0
# 수위(E지역).3    0
# 수위(D지역).3    0
# 유역평균강수.4     0
# 강우(A지역).4    0
# 강우(B지역).4    0
# 강우(C지역).4    0
# 강우(D지역).4    0
# 수위(E지역).4    0
# 수위(D지역).4    0
# 유역평균강수.5     0
# 강우(A지역).5    0
# 강우(B지역).5    0
# 강우(C지역).5    0
# 강우(D지역).5    0
# 수위(E지역).5    0
# 수위(D지역).5    0
# dtype: int64

# %%
a
# Out:
#          연  월   일  시간         유입량   유역평균강수  강우(A지역)  강우(B지역)  강우(C지역)  \
# 0     2006  7  10   8  189.100000   6.4000        7        7        7
# 1     2006  7  10   9  216.951962   6.3000        7        8        7
# 2     2006  7  10  10  251.424419   6.4000        7        9        7
# 3     2006  7  10  11  302.812199   7.3000        7       10        7
# 4     2006  7  10  12  384.783406   8.2000        7       12        8
# ...    ... ..  ..  ..         ...      ...      ...      ...      ...
# 2886  2017  7  18  18  513.368437  22.7836        6        0        1
# 2887  2017  7  18  19  502.846843   8.2586        2        0        1
# 2888  2017  7  18  20  491.954805   4.1089        1        0        1
# 2889  2017  7  18  21  481.103083   3.3854        1        0        1
# 2890  2017  7  18  22  470.458109   3.2841        1        0        1
#
#       강우(D지역)  ...  강우(D지역).4  수위(E지역).4  수위(D지역).4  유역평균강수.5  강우(A지역).5  \
# ...

# %%
b
# Out:
#              유입량
# 0     189.100000
# 1     216.951962
# 2     251.424419
# 3     302.812199
# 4     384.783406
# ...          ...
# 2886  513.368437
# 2887  502.846843
# 2888  491.954805
# 2889  481.103083
# 2890  470.458109
#
# [2891 rows x 1 columns]

# %%
import seaborn as sns
from matplotlib import font_manager, rc 
import matplotlib.pyplot as plt 
font_name = font_manager.FontProperties(fname = "C:/Windows/Fonts/malgun.ttf").get_name() 
rc('font', family = font_name)

# %%
plt.figure(figsize = (15, 10))
sns.heatmap(data = a.corr(), annot = True, fmt = '.2f', linewidths = .5, cmap = 'Blues')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
a.drop('유입량', axis = 1, inplace = True)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %%
tree = DecisionTreeRegressor()

# %%
X_train, X_test, y_train, y_test = train_test_split(a, b, test_size = 0.2, random_state = 11)

# %%
X_train.shape
# Out:
# (2312, 46)

# %%
X_test.shape
# Out:
# (579, 46)

# %%
y_train.shape
# Out:
# (2312, 1)

# %%
y_test.shape
# Out:
# (579, 1)

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
pred = tree.predict(X_test)

# %%
y_test
# Out:
#               유입량
# 416    605.245612
# 1527   808.724543
# 329    192.359576
# 394   2200.256335
# 395   2279.664519
# ...           ...
# 881   3178.189378
# 1862   155.964924
# 1822  3602.911206
# 1757   649.028132
# 1750   786.537898
#
# [579 rows x 1 columns]

# %%
pd.DataFrame(pred)
# Out:
#                0
# 0    1048.463258
# 1     828.014158
# 2     200.343166
# 3    1722.384234
# 4    2340.484465
# ..           ...
# 574  3287.834459
# 575   142.534389
# 576  3820.948752
# 577   650.281284
# 578   796.434390
#
# [579 rows x 1 columns]

# %%
## LSTM으로 아파트지수 예측하기

# %%
X_train_t = X_train.values
X_test_t = X_test.values

# %%
X_train_tt = X_train_t.reshape(X_train_t.shape[0], 46, 1)
X_test_tt = X_test_t.reshape(X_test_t.shape[0], 46, 1)

# %%
X_train_tt
# Out:
# array([[[2.00600e+03],
#         [7.00000e+00],
#         [1.80000e+01],
#         ...,
#         [9.70000e+01],
#         [8.21000e+00],
#         [1.42905e+02]],
#
#        [[2.01200e+03],
#         [8.00000e+00],
#         [2.30000e+01],
#         ...,
#         [8.00000e+01],
#         [5.16000e+00],
#         [1.33035e+02]],
#
#        [[2.01000e+03],
#         [9.00000e+00],
#         [9.00000e+00],
#         ...,
#         [0.00000e+00],
#         [3.07000e+00],
#         [1.33895e+02]],
#
#        ...,
#
#        [[2.01100e+03],
#         [7.00000e+00],
#         [1.10000e+01],
#         ...,
#         [4.20000e+01],
#         [4.70000e+00],
#         [1.37775e+02]],
#
#        [[2.01100e+03],
#         [6.00000e+00],
#         [3.00000e+01],
#         ...,
#         [9.10000e+01],
#         [7.35000e+00],
#         [1.33615e+02]],
#
#        [[2.01200e+03],
#         [8.00000e+00],
#         [1.50000e+01],
#         ...,
#         [1.00000e+00],
#         [1.84000e+00],
# ...

# %%
from keras.layers import LSTM, Dense,SimpleRNN
from keras.models import Sequential
from keras.callbacks import EarlyStopping
import keras.backend as K

# %%
K.clear_session()

# %%
model = Sequential()
model.add(SimpleRNN(128, input_shape=(X_train_tt.shape[1], X_train_tt.shape[2]), activation = 'relu', return_sequences = True))
model.add(LSTM(64, activation = 'relu',return_sequences = True))
model.add(LSTM(32, activation = 'relu'))
model.add(Dense(1))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# simple_rnn_1 (SimpleRNN)     (None, 46, 128)           16640
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 46, 64)            49408
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# ...
# Total params: 78,497
# Trainable params: 78,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
# early_stop = EarlyStopping(monitor = 'loss', patience = 1, verbose = 1)
model.fit(X_train_tt, y_train, epochs = 50, batch_size = 20, verbose = 1)
# Out:
# Epoch 1/50
# 2312/2312 [==============================] - 19s 8ms/step - loss: 31161869.3088
# Epoch 2/50
# 2312/2312 [==============================] - 15s 6ms/step - loss: 11874160.2634
# Epoch 3/50
# 2312/2312 [==============================] - 16s 7ms/step - loss: 14490921.1442
# Epoch 4/50
# 2312/2312 [==============================] - 15s 7ms/step - loss: 7043023.8450
# Epoch 5/50
# 2312/2312 [==============================] - 16s 7ms/step - loss: 28119279626.8668
# Epoch 6/50
# 2312/2312 [==============================] - 17s 7ms/step - loss: 3342063827.3155
# Epoch 7/50
# 2312/2312 [==============================] - 15s 7ms/step - loss: 6668772.6992
# Epoch 8/50
# 2312/2312 [==============================] - 16s 7ms/step - loss: 5437795.5415
# Epoch 9/50
# 2312/2312 [==============================] - 16s 7ms/step - loss: 5207006.2076
# Epoch 10/50
# 2312/2312 [==============================] - 15s 7ms/step - loss: 5137642.2202: 1s - loss: 4704002 - ETA: 0s - loss: 482300
# ...

# %%
score = model.evaluate(X_test_tt, y_test, batch_size = 20)
print(score)
# Out:
# 579/579 [==============================] - 1s 2ms/step
# 3271179.756476684

# %%
X_train
# Out:
#          연  월   일  시간    유역평균강수  강우(A지역)  강우(B지역)  강우(C지역)  강우(D지역)  수위(E지역)  \
# 193   2006  7  18   9  286.9000      114      293      168      134     8.21
# 2149  2012  8  23  22   71.6169       58       72       46       81     5.16
# 833   2010  9   9  20    0.8196        0        1        1        0     3.07
# 2098  2012  8  21  19   22.5184       37       11       17        9     2.39
# 2748  2017  7   3  19  110.4654      157      141      107       49     5.14
# ...    ... ..  ..  ..       ...      ...      ...      ...      ...      ...
# 1697  2011  8  18   9  144.6303       79      112      159      222     7.35
# 332   2007  8   3  23   12.8000        6        6        1        0     2.59
# 1293  2011  7  11  24   46.5429       36       37       50       47     4.70
# 1104  2011  6  30  15   86.9740      142       76      102       91     7.35
# 1945  2012  8  15  10   37.7324       15       10        0        1     1.84
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

scaler = MinMaxScaler()
scaled_cols = X_train.columns
h_scaled = scaler.fit_transform(X_train[scaled_cols])
h_scaled = pd.DataFrame(h_scaled)
h_scaled.columns = scaled_cols

h_scaled['월'] = np.array(X_train['월'])
h_scaled['연'] = np.array(X_train['연'])
h_scaled['일'] = np.array(X_train['일'])
h_scaled['시간'] = np.array(X_train['시간'])
h_scaled
# Out:
#          연  월   일  시간    유역평균강수   강우(A지역)   강우(B지역)   강우(C지역)   강우(D지역)  \
# 0     2006  7  18   9  0.873630  0.346505  0.798365  0.664032  0.511450
# 1     2012  8  23  22  0.218078  0.176292  0.196185  0.181818  0.309160
# 2     2010  9   9  20  0.002496  0.000000  0.002725  0.003953  0.000000
# 3     2012  8  21  19  0.068570  0.112462  0.029973  0.067194  0.034351
# 4     2017  7   3  19  0.336375  0.477204  0.384196  0.422925  0.187023
# ...    ... ..  ..  ..       ...       ...       ...       ...       ...
# 2307  2011  8  18   9  0.440409  0.240122  0.305177  0.628458  0.847328
# 2308  2007  8   3  23  0.038977  0.018237  0.016349  0.003953  0.000000
# 2309  2011  7  11  24  0.141726  0.109422  0.100817  0.197628  0.179389
# 2310  2011  6  30  15  0.264842  0.431611  0.207084  0.403162  0.347328
# 2311  2012  8  15  10  0.114898  0.045593  0.027248  0.000000  0.003817
#
#        수위(E지역)  ...  강우(D지역).4  수위(E지역).4  수위(D지역).4  유역평균강수.5  강우(A지역).5  \
# ...

# %%
TEST_SIZE = 1000
WINDOW_SIZE = 20

train = h_scaled[:-TEST_SIZE]
test = h_scaled[-TEST_SIZE:]

# %%
def make_dataset(data, label, window_size = 20):
    feature_list = []
    label_list = []
    for i in range(len(data)-window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
from sklearn.model_selection import train_test_split

feature_cols = X_train.columns
label_cols = y_train.columns

train_feature = X_train[feature_cols]
train_label = y_train[label_cols]

train_feature, train_label = make_dataset(train_feature, train_label, 10)

x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size = 0.2)
x_train.shape, x_valid.shape
# Out:
# ((1841, 10, 46), (461, 10, 46))

# %%
test_feature = X_test[feature_cols]
test_label = y_test[label_cols]

test_feature.shape, test_label.shape
# Out:
# ((579, 46), (579, 1))

# %%
test_feature, test_label = make_dataset(test_feature, test_label, 20)
test_feature.shape, test_label.shape
# Out:
# ((559, 20, 46), (559, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM

model = Sequential()
model.add(LSTM(32, input_shape = (train_feature.shape[1], train_feature.shape[2]),
              activation = 'relu', return_sequences = False))
model.add(Dense(1))  # 예측하고자 하는 target 개수

# %%
import os

model.compile(loss = 'mean_squared_error', optimizer = 'adam')
early_stop = EarlyStopping(monitor = 'val_loss', patience = 5)

history = model.fit(x_train, y_train, epochs = 50, batch_size = 20,
                   validation_data = (x_valid, y_valid))
# Out:
# Train on 1841 samples, validate on 461 samples
# Epoch 1/50
# 1841/1841 [==============================] - 1s 581us/step - loss: 6264988.5012 - val_loss: 3035049.2972
# Epoch 2/50
# 1841/1841 [==============================] - 1s 373us/step - loss: 5801191.0147 - val_loss: 2994959.0719
# Epoch 3/50
# 1841/1841 [==============================] - 1s 372us/step - loss: 5777490.2353 - val_loss: 2984643.6104
# Epoch 4/50
# 1841/1841 [==============================] - 1s 366us/step - loss: 5765361.9032 - val_loss: 3006133.3256
# Epoch 5/50
# 1841/1841 [==============================] - 1s 376us/step - loss: 5772580.1110 - val_loss: 3030684.5254
# Epoch 6/50
# 1841/1841 [==============================] - 1s 374us/step - loss: 5778163.7321 - val_loss: 3165799.9326
# Epoch 7/50
# 1841/1841 [==============================] - 1s 375us/step - loss: 5928518.7557 - val_loss: 2983685.2331
# Epoch 8/50
# ...

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_7 (LSTM)                (None, 32)                10112
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# ...
# Total params: 10,145
# Trainable params: 10,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
score = model.evaluate(X_test, y_test, batch_size = 20)
print(score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-d1a55822c56f> in <module>
# ----> 1 score = model.evaluate(X_test, y_test, batch_size = 20)
#       2 print(score)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1347             x, y,
#    1348             sample_weight=sample_weight,
# -> 1349             batch_size=batch_size)
#    1350         # Prepare inputs, delegate logic to `test_loop`.
#    1351         if self._uses_dynamic_learning_phase():
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     577             feed_input_shapes,
# ...

# %%
pd.DataFrame.from_dict(history.history).plot()

# %%
plt.figure(figsize=(25,16))
plt.plot(test_label, label = 'actual')
plt.plot(pred, label = 'prediction')
plt.legend()
plt.show()

# %%
score = model.evaluate(X_test_tt, y_test, batch_size = 20)
print(score)

# %%
import xgboost as xgb
from sklearn.metrics import explained_variance_score

# %%
xgb_model = xgb.XGBRegressor(n_estimators = 100, learning_rate = 0.08, gamma = 0, subsample = 0.75,
                            colsample_bytree = 1, max_depth = 9)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.08, max_delta_step=0, max_depth=9,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=0.75,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgb.plot_importance(xgb_model)

# %%
pred = xgb_model.predict(X_test)
pred
# Out:
# array([  608.14075 ,   799.44507 ,   217.66658 ,  2132.899   ,
#         2173.4307  ,  2240.5469  ,   454.1944  ,  1039.158   ,
#         6287.0015  ,    73.99379 ,   208.49878 ,   948.9528  ,
#         1053.1576  ,  2375.243   ,   123.0614  ,   591.5734  ,
#         6024.9287  ,   319.61996 ,   120.03887 ,   446.58447 ,
#          435.32895 ,  1508.0173  ,  1042.1539  ,  2200.619   ,
#         2145.4722  ,   159.06366 ,  5574.0063  ,   471.08743 ,
#           70.172905,   277.33752 ,   146.228   ,   637.38416 ,
#         1078.9065  ,   861.878   ,  6929.131   ,  2823.8796  ,
#          160.66599 ,   746.2567  ,  1677.1095  ,  1920.473   ,
#         1736.1602  ,  3710.9507  ,   281.74933 ,  1968.0577  ,
#         4822.612   ,  1099.0653  ,  3235.012   ,   578.92554 ,
#         1743.1017  ,   149.31847 ,   181.66595 ,   182.9241  ,
#         1494.0269  ,   174.05933 ,  2264.4246  ,  3452.1694  ,
#         2490.4114  ,  4093.7234  ,   236.2938  ,   184.92526 ,
# ...

# %%
y_test
# Out:
#               유입량
# 416    605.245612
# 1527   808.724543
# 329    192.359576
# 394   2200.256335
# 395   2279.664519
# ...           ...
# 881   3178.189378
# 1862   155.964924
# 1822  3602.911206
# 1757   649.028132
# 1750   786.537898
#
# [579 rows x 1 columns]

# %%
y_test.reset_index(inplace = True)

# %%
y_test.drop('index', axis = 1, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
xgb_model.score(X_train,y_train)
# Out:
# 0.9998935138565453

# %%
print(explained_variance_score(pred, y_test))
# Out:
# 0.9910338979799327

# %%
plt.figure(figsize=(25,16))
plt.plot(y_test, label = 'actual')
plt.plot(pred, label = 'prediction')
plt.legend()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(a, b, test_size = 0.2, random_state = 14)

# %%
xgb_model = xgb.XGBRegressor(n_estimators = 300, learning_rate = 0.08, gamma = 0, subsample = 0.75,
                            colsample_bytree = 1, max_depth = 9)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.08, max_delta_step=0, max_depth=9,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=300, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=0.75,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgb.plot_importance(xgb_model)

# %%
pred = xgb_model.predict(X_test)
pred
# Out:
# array([1.49865710e+03, 2.58831348e+03, 2.26622729e+03, 1.38650818e+03,
#        4.52981494e+03, 9.80878540e+02, 1.54387122e+03, 8.22738586e+02,
#        1.38909399e+03, 2.80460846e+02, 1.04228687e+03, 1.50420483e+03,
#        2.86943311e+03, 6.34537903e+02, 1.14206787e+03, 1.09001794e+03,
#        5.96626807e+03, 8.45974304e+02, 3.24791235e+03, 5.90173889e+02,
#        5.31778625e+02, 1.47166122e+02, 2.46666260e+02, 2.31499536e+03,
#        1.47557642e+03, 4.40693726e+02, 1.88618115e+03, 1.38034607e+03,
#        4.01118872e+03, 1.88997729e+03, 1.19371680e+03, 1.38250412e+02,
#        1.64543311e+03, 2.45849854e+02, 2.79621680e+03, 3.02957001e+02,
#        2.30073105e+02, 5.12366211e+02, 6.04170850e+03, 5.20145935e+02,
#        8.98341895e+03, 5.82841736e+02, 1.31255859e+02, 6.35852930e+03,
#        3.69810181e+03, 2.58362427e+03, 1.15446497e+03, 3.32427173e+03,
#        9.38124939e+02, 2.46071973e+03, 1.42548962e+03, 1.01722771e+02,
# ...

# %%
pd.DataFrame(y_test.values, pred)
# Out:
#                        0
# 1498.657104  1477.529214
# 2588.313477  2564.597286
# 2266.227295  2295.126766
# 1386.508179  1353.103343
# 4529.814941  4495.458857
# ...                  ...
# 95.908257      87.955369
# 2476.531006  2446.864849
# 112.964577    110.605328
# 1464.171875  1503.512821
# 2162.159424  1880.147132
#
# [579 rows x 1 columns]

# %%
y_test.reset_index(inplace = True)

# %%
y_test.drop('index', axis = 1, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
xgb_model.score(X_train,y_train)
# Out:
# 0.9999966661246058

# %%
print(explained_variance_score(pred, y_test))
# Out:
# 0.9917526134819823

# %%
plt.figure(figsize=(25,16))
plt.plot(y_test, label = 'actual')
plt.plot(pred, label = 'prediction')
plt.legend()
plt.show()

# %%
RMSE = mean_squared_error(y_test, pred)**0.5

# %%
RMSE
# Out:
# 182.85566649081886

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators':[100,200,300, 400, 500], 'max_depth':[6, 8, 10, 12, 14]}
grid_search = GridSearchCV(xgb_model, param_grid = param_grid)

# %%
param_grid = {'n_estimators':[500, 600, 700, 800, 900, 1000], 'max_depth':[6, 8, 10, 12, 14]}
grid_search = GridSearchCV(xgb_model, param_grid = param_grid)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0, gpu_id=-1,
#                                     importance_type='gain',
#                                     interaction_constraints='',
#                                     learning_rate=0.08, max_delta_step=0,
#                                     max_depth=9, min_child_weight=1,
#                                     missing=nan, monotone_constraints='()',
#                                     n_estimators=300, n_jobs=0,
#                                     n...
#                                     objective='reg:squarederror',
#                                     random_state=0, reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, subsample=0.75,
# ...

# %%
print(grid_search.best_params_)
# Out:
# {'max_depth': 6, 'n_estimators': 1000}

# %%
print(grid_search.best_score_)
# Out:
# 0.990321448747802

# %%
temp = grid_search.predict(X_test)
temp
# Out:
# array([1.52973792e+03, 2.53881982e+03, 2.29271851e+03, 1.40593591e+03,
#        4.43464307e+03, 9.70763550e+02, 1.58306750e+03, 8.31141296e+02,
#        1.34362317e+03, 2.74998108e+02, 1.02899170e+03, 1.52700391e+03,
#        2.89467212e+03, 6.30435791e+02, 1.06836914e+03, 1.10150574e+03,
#        6.13023340e+03, 9.40529480e+02, 2.99456152e+03, 5.79542236e+02,
#        5.68579834e+02, 1.60277832e+02, 2.46803513e+02, 2.38359766e+03,
#        1.47957617e+03, 5.71582275e+02, 1.94474817e+03, 1.38531323e+03,
#        4.04048730e+03, 1.89899292e+03, 1.21142065e+03, 1.37940079e+02,
#        1.58916479e+03, 2.61726227e+02, 2.75668384e+03, 2.96626129e+02,
#        2.39817505e+02, 5.16344421e+02, 5.88157324e+03, 5.13756897e+02,
#        9.00280469e+03, 6.02236328e+02, 1.30865005e+02, 6.25839014e+03,
#        3.93829517e+03, 2.53983276e+03, 1.16989526e+03, 3.34702490e+03,
#        9.58319214e+02, 2.37583765e+03, 1.40188696e+03, 1.21853737e+02,
# ...

# %%
pd.DataFrame(y_test.values, temp)
# Out:
#                        0
# 1529.737915  1477.529214
# 2538.819824  2564.597286
# 2292.718506  2295.126766
# 1405.935913  1353.103343
# 4434.643066  4495.458857
# ...                  ...
# 95.339371      87.955369
# 2412.029541  2446.864849
# 121.983772    110.605328
# 1411.501587  1503.512821
# 2114.789551  1880.147132
#
# [579 rows x 1 columns]

# %%
plt.figure(figsize=(25,16))
plt.plot(y_test, label = 'actual')
plt.plot(temp, label = 'prediction')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
RMSE = mean_squared_error(y_test, temp)**0.5

# %%
RMSE
# Out:
# 180.1735488762559
